# %% [markdown]
# <a href="https://colab.research.google.com/github/nandukamankar/CLASSIFICATION-PROJECT/blob/main/Copy_of_Classification_Mobile_price_range_prediction_nandu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  **PROJECT TITLE :- Mobile Price Range Prediction.**

# %% [markdown]
# # Project Type :- Capstone Project - Classification

# %% [markdown]
# **Contribution :- Team**

# %% [markdown]
# Team Member 1 :- Deepak Singh
#
# Team Member 2 :- Nandu Kamankar

# %% [markdown]
# # **PROJECT SUMMARY :-**
#
#
# The project aims to provide a better understanding of the factors influencing mobile phone prices in the competitive market. By categorizing price ranges and analyzing the relationship between features and price, the project will offer insights for mobile phone companies to make informed decisions about pricing and product positioning.
#
# Approach:
#
# * Data Collection: Gather a comprehensive dataset containing information about mobile phone models, their features, and corresponding selling prices.
#
# * Data Preprocessing: Clean the dataset by handling missing values, removing outliers, and normalizing numerical features.
# * Feature Selection: Identify the relevant features that are likely to have a significant impact on the mobile phone prices, such as RAM, internal memory, processor, camera quality, display size, etc.
# * Price Range Categorization: Group the mobile phones into distinct price ranges based on their selling prices.
# * Statistical Analysis: Conduct a statistical analysis to explore the relationship between the selected features and the price ranges. This may involve techniques such as correlation analysis, hypothesis testing, and regression analysis.
# * Visualization: Create visual representations, such as scatter plots, box plots, and histograms, to illustrate the relationship between features and price ranges.
# * Insights and Recommendations: Interpret the findings and derive insights into the factors that drive mobile phone prices. Provide recommendations to mobile phone companies for pricing strategies based on the identified relationships.

# %% [markdown]
# # **GitHub Link :-** https://github.com/nandukamankar/CLASSIFICATION-PROJECT

# %% [markdown]
# # **Problem Statement:-**
#
# In the highly competitive mobile phone market, it is crucial for companies to have a deep understanding of the sales data and factors that drive the prices of mobile phones. The objective of this project is to identify the relationship between various features of mobile phones, such as RAM, internal memory, processor, camera quality, display size, etc., and their selling prices. Instead of predicting the exact price, the goal is to categorize the price range, indicating the relative level of pricing. By addressing this problem, we aim to answer the following research question:
#
# What are the key factors influencing the price ranges of mobile phones, and how can mobile phone companies leverage this information to optimize their pricing strategies?

# %% [markdown]
# # **Data Description:-**
#
# **<u>Data fields</u>**
#
# *  **Battery_power** - Total energy a battery can store in one time measured in mAh
# *   **Blue** - Has bluetooth or not
# *   **Clock_speed** - speed at which microprocessor executes instructions
# *   **Dual_sim** - Has dual sim support or not
# *   **Fc** - Front Camera mega pixels
# *  **Four_g** - Has 4G or not
# *  **Int_memory** - Internal Memory in Gigabytes
# *   **M_dep** - Mobile Depth in cm
# *   **Mobile_wt** - Weight of mobile phone
# *   **N_cores** - Number of cores of processor
# *   **Pc** - Primary Camera mega pixels
# *   **Px_height** - Pixel Resolution Height
# *   **Px_width** - Pixel Resolution Width
# *   **Ram** - Random Access Memory in Mega
# *   **Touch_screen** - Has touch screen or not
# *   **Wifi** - Has wifi or not
# *  **Sc_h** - Screen Height of mobile in cm
# *   **Sc_w** - Screen Width of mobile in cm
# *   **Talk_time** - longest time that a single battery charge will last when you are
# *   **Three_g** - Has 3G or not
# *   **Wifi** - Has wifi or not
# *  **Price_range** - This is the target variable with value of 0(low cost), 1(medium cost),
# 2(high cost) and 3(very high cost).

# %% [markdown]
# ##**Business Problem**
#
# **In the competitive mobile phone market companies want
# to understand sales data of mobile phones and factors which drive the prices.
# The objective is to find out some relation between features of a mobile phone(eg:- RAM,
# Internal Memory, etc) and its selling price. In this problem, we do not have to predict the
# actual price but a price range indicating how high the price is**

# %%
# Importing  all necessary libraries:-

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import StackingClassifier
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore")

# %%
# Mounting the drive:-

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Loading the dataset:-

df = pd.read_csv('/content/drive/MyDrive/almabetter/project_work/CLASSIFICATION PROJECT/data mobile price range.csv')

# %% [markdown]
# # **DATA EXPLORATION**

# %%
# Looking at the first 5 Rows of the Dataset.

df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
# Looking at the last 5 Rows of the Dataset.

df.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
# Checking the shape of the dataset.

df.shape
# Out:
# (2000, 21)

# %% [markdown]
# We have total 2000 Rows and 21 columns in tha dataset.

# %%
# Checking the information about the dataset.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# There are total 2000 rows/observations and 21 columns in this dataset.There seems to be Null values present in it. It has int64 & float64 as data types.

# %%
# Checking the names of the columns:-

df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# Checking the description of the data-
df.describe()
df.describe().T # transpose
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %% [markdown]
# Here from this we can se that the minimum value of px_height and sc_w cannot be zero so we need to handle that.

# %%
# Total phones with sc_w = 0

print(len(df[df.sc_w == 0]))

# Total phones with px_height = 0

print(len(df[df.px_height == 0]))
# Out:
# 180
# 2

# %%
# Where ther is sc_W and px_height is zero ,assigning mean values:-

df['sc_w'][df[df.sc_w == 0].index] = df.sc_w.mean()

df['px_height'][df[df.px_height == 0].index] = df.px_height.mean()

# %%
# Checking whether there is duplicates or not.

len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# There are no duplicate values.

# %%
# The nunique () method returns the number of unique values for each column
df.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %% [markdown]
# # **Exploratory Data Analysis:-**

# %%
# Plotting Bar Chart for the Price:-

sns.set()
price_plot=df['price_range'].value_counts().plot(kind='bar')
plt.xlabel('Price_range')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Mobile phones are available in four different price ranges, with the quantity of options being nearly identical.

# %%
# Plotting Bar Chart for the Battery power:-

sns.set(rc={'figure.figsize':(5,5)})
ax=sns.displot(df["battery_power"])
plt.show()

# %% [markdown]
# The depicted graph demonstrates the distribution of battery mAh across different price ranges, revealing a steady incline as the prices rise.

# %%
# Plotting Bar Chart for the Bluetooth:-

fig,ax=plt.subplots(figsize=(10,5))
sns.barplot(data=df,x='blue',y='price_range',ax=ax)
plt.show()

# %% [markdown]
# Based on the bar chart, it is evident that Bluetooth is present in half of the devices, while the other half lacks this feature.

# %%
# Plotting the scatter plot for Ram:-

df.plot(x='price_range',y='ram',kind='scatter')
plt.show()

# %% [markdown]
# As Ram moves from the low-cost range to the very high-cost range, there is a consistent upward trajectory in prices.

# %%
# Creating a kernel density estimate (KDE) plot & Box plot for px_width & price_range:-

fig, axs = plt.subplots(1,2, figsize=(15,5))
sns.kdeplot(data=df, x='px_width', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range', y='px_width', ax=axs[1])
plt.show()

# %% [markdown]
# The pixel width does not consistently increase as we transition from Low cost to Very high cost. Instead, Mobiles with 'Medium cost' and 'High cost' exhibit nearly identical pixel width. This observation suggests that pixel width could play a significant role in determining the price range.

# %%
# Creating a kernel density estimate (KDE) plot & Box plot for px_heigth & price_range:-

fig, axs = plt.subplots(1,2, figsize=(15,5))
sns.kdeplot(data=df, x='px_height', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range', y='px_height', ax=axs[1])
plt.show()

# %% [markdown]
# As we transition from low-cost to high-cost options, there is minimal variation in the pixel height, which remains relatively consistent.

# %%
# Plotting a scatter plot for FC (Front Camera megapixels):-

df.plot(x='price_range',y='fc',kind='scatter')
plt.show()

# %% [markdown]
# The distribution of these features remains relatively consistent across all price ranges, rendering it less informative for predictive purposes.
